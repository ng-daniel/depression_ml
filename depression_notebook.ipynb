# %%
import pandas as pd
import matplotlib.pyplot as plt

condition_1 = pd.read_csv("./data/condition/condition_1.csv")
condition_1.head(), condition_1.shape
# Out:
# (             timestamp        date  activity
#  0  2003-05-07 12:00:00  2003-05-07         0
#  1  2003-05-07 12:01:00  2003-05-07       143
#  2  2003-05-07 12:02:00  2003-05-07         0
#  3  2003-05-07 12:03:00  2003-05-07        20
#  4  2003-05-07 12:04:00  2003-05-07       166,
#  (23244, 3))

# %%
def plot_activity_freq(data, min_frequency):
        activity_frequency = data.activity.value_counts()
        activity_frequency_nooutlier = activity_frequency[(activity_frequency > min_frequency) & (activity_frequency.index != 0)]
        plt.bar(x=activity_frequency_nooutlier.index, 
                height=activity_frequency_nooutlier, 
                width=2,
                log=True)
        plt.xlabel("Hourly Recorded Activity")
        plt.ylabel("# of Occurences")

# %%
scores_df = pd.read_csv("./data/scores.csv", index_col='number')
scores_df.head()
# Out:
#              days  gender    age  afftype  melanch  inpatient    edu  \
# number
# condition_1    11       2  35-39      2.0      2.0        2.0   6-10
# condition_2    18       2  40-44      1.0      2.0        2.0   6-10
# condition_3    13       1  45-49      2.0      2.0        2.0   6-10
# condition_4    13       2  25-29      2.0      2.0        2.0  11-15
# condition_5    13       2  50-54      2.0      2.0        2.0  11-15
#
#              marriage  work  madrs1  madrs2
# number
# condition_1       1.0   2.0    19.0    19.0
# condition_2       2.0   2.0    24.0    11.0
# condition_3       2.0   2.0    24.0    25.0
# condition_4       1.0   1.0    20.0    16.0
# condition_5       2.0   2.0    26.0    26.0

# %%
scores_days_sorted = scores_df.days.sort_values()
plt.figure(figsize=(14,9))
plt.barh(y=scores_days_sorted.index, width=scores_days_sorted)
# Out:
# <BarContainer object of 55 artists>

# %%
import datetime

def encode_time(df):
    df = df.copy()
    df['time_parsed'] = pd.to_datetime(df['timestamp'], format="%Y-%m-%d %H:%M:%S")
    df['day_of_week'] = df.time_parsed.dt.dayofweek
    df['hour'] = df.time_parsed.dt.hour
    return df

condition_1_parsed = encode_time(condition_1)
condition_1_parsed
# Out:
#                  timestamp        date  activity         time_parsed  \
# 0      2003-05-07 12:00:00  2003-05-07         0 2003-05-07 12:00:00
# 1      2003-05-07 12:01:00  2003-05-07       143 2003-05-07 12:01:00
# 2      2003-05-07 12:02:00  2003-05-07         0 2003-05-07 12:02:00
# 3      2003-05-07 12:03:00  2003-05-07        20 2003-05-07 12:03:00
# 4      2003-05-07 12:04:00  2003-05-07       166 2003-05-07 12:04:00
# ...                    ...         ...       ...                 ...
# 23239  2003-05-23 15:19:00  2003-05-23         0 2003-05-23 15:19:00
# 23240  2003-05-23 15:20:00  2003-05-23         0 2003-05-23 15:20:00
# 23241  2003-05-23 15:21:00  2003-05-23         0 2003-05-23 15:21:00
# 23242  2003-05-23 15:22:00  2003-05-23         0 2003-05-23 15:22:00
# 23243  2003-05-23 15:23:00  2003-05-23       533 2003-05-23 15:23:00
#
#        day_of_week  hour
# 0                2    12
# 1                2    12
# 2                2    12
# 3                2    12
# 4                2    12
# ...            ...   ...
# 23239            4    15
# 23240            4    15
# 23241            4    15
# 23242            4    15
# 23243            4    15
#
# [23244 rows x 6 columns]

# %%
weekday_counts = condition_1_parsed.day_of_week.value_counts()
plt.bar(x=weekday_counts.index, height=weekday_counts)
# Out:
# <BarContainer object of 7 artists>

# %%
weekday_counts
# Out:
# day_of_week
# 3    4320
# 4    3804
# 2    3600
# 5    2880
# 6    2880
# 0    2880
# 1    2880
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,4))
plt.plot(control_17.index, control_17.activity)
plt.plot(condition_1.index, condition_1.activity)

# %%
import torch
